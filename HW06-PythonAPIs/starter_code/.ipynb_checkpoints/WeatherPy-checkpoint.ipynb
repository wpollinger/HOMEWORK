# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy #citypy https://github.com/wingchen/citipy/tree/master/citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv" 

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city.replace(" ", "%20"))
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 776

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#x = 0 #counter 
#city_name = []
#url = "http://api.openweathermap.org/data/2.5/weather"
#param =  {'appid': api_key, 'q':cities[x]}
#response = requests.get(url,param).json()
#city_name.append(response["name"])
#city_name

# %%
x = 0 #counter 
y = 1 #set counter
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print("Beginning Data Retrieval")     
print("-----------------------------")
for a in cities:
    try:
        url = "http://api.openweathermap.org/data/2.5/weather"
        param =  {'appid': api_key, 'q':cities[x]}
        response = requests.get(url,param).json()
        city_name.append(response["name"].replace("%20", " "))
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record:{y} of set {y} | {cities[x]} ")
        x = x+1 
        y = y +1
        time.sleep(0.05)
        if x==len(cities):
            print("------------------------------")
            print("Data Retrieval Complete")
            print("------------------------------")
            break
    except:
        cities[x] = cities[x].replace("%20", " ")
        print(f"City not found. Skipping...")
        x = x+1 
        time.sleep(0.05)
        if x==len(cities):
            print("------------------------------")
            print("Data Retrieval Complete")
            print("------------------------------")
            break
    continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record:1 of set 1 | vao
# Processing Record:2 of set 2 | georgetown
# Processing Record:3 of set 3 | butaritari
# Processing Record:4 of set 4 | sioux lookout
# Processing Record:5 of set 5 | beloha
# Processing Record:6 of set 6 | mataura
# Processing Record:7 of set 7 | mar del plata
# City not found. Skipping...
# Processing Record:8 of set 8 | avarua
# Processing Record:9 of set 9 | sobolevo
# City not found. Skipping...
# Processing Record:10 of set 10 | thompson
# Processing Record:11 of set 11 | jalu
# Processing Record:12 of set 12 | mehamn
# Processing Record:13 of set 13 | port elizabeth
# Processing Record:14 of set 14 | lompoc
# Processing Record:15 of set 15 | hilo
# Processing Record:16 of set 16 | port alfred
# Processing Record:17 of set 17 | vaini
# Processing Record:18 of set 18 | albany
# Processing Record:19 of set 19 | hobart
# Processing Record:20 of set 20 | valeni
# Processing Record:21 of set 21 | fort nelson
# Processing Record:22 of set 22 | barrow
# Processing Record:23 of set 23 | sovetskaya gavan
# Processing Record:24 of set 24 | bredasdorp
# City not found. Skipping...
# Processing Record:25 of set 25 | victoria
# Processing Record:26 of set 26 | kruisfontein
# Processing Record:27 of set 27 | tomatlan
# City not found. Skipping...
# Processing Record:28 of set 28 | kurchum
# Processing Record:29 of set 29 | biak
# Processing Record:30 of set 30 | rikitea
# Processing Record:31 of set 31 | te anau
# City not found. Skipping...
# Processing Record:32 of set 32 | ancud
# Processing Record:33 of set 33 | new norfolk
# Processing Record:34 of set 34 | san juan
# Processing Record:35 of set 35 | honiara
# Processing Record:36 of set 36 | jamestown
# Processing Record:37 of set 37 | upernavik
# Processing Record:38 of set 38 | mahebourg
# Processing Record:39 of set 39 | punta arenas
# Processing Record:40 of set 40 | punta arenas
# Processing Record:41 of set 41 | ahipara
# Processing Record:42 of set 42 | cape town
# Processing Record:43 of set 43 | saldanha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:44 of set 44 | arraial do cabo
# Processing Record:45 of set 45 | katsuura
# Processing Record:46 of set 46 | ushuaia
# Processing Record:47 of set 47 | ribeira grande
# Processing Record:48 of set 48 | port alfred
# Processing Record:49 of set 49 | kodiak
# Processing Record:50 of set 50 | busselton
# City not found. Skipping...
# Processing Record:51 of set 51 | lhokseumawe
# Processing Record:52 of set 52 | tura
# City not found. Skipping...
# Processing Record:53 of set 53 | pangkalanbuun
# City not found. Skipping...
# Processing Record:54 of set 54 | talnakh
# Processing Record:55 of set 55 | vestmannaeyjar
# Processing Record:56 of set 56 | bathsheba
# City not found. Skipping...
# Processing Record:57 of set 57 | oskemen
# Processing Record:58 of set 58 | tafresh
# City not found. Skipping...
# Processing Record:59 of set 59 | faya
# Processing Record:60 of set 60 | lavrentiya
# Processing Record:61 of set 61 | vostok
# Processing Record:62 of set 62 | dingle
# Processing Record:63 of set 63 | bossangoa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:64 of set 64 | caravelas
# Processing Record:65 of set 65 | ayan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:66 of set 66 | dafeng
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:67 of set 67 | plettenberg bay
# Processing Record:68 of set 68 | punta arenas
# Processing Record:69 of set 69 | tourlaville
# Processing Record:70 of set 70 | narsaq
# Processing Record:71 of set 71 | port blair
# Processing Record:72 of set 72 | sistranda
# Processing Record:73 of set 73 | hermanus
# Processing Record:74 of set 74 | cape town
# Processing Record:75 of set 75 | saint-philippe
# City not found. Skipping...
# Processing Record:76 of set 76 | fuerte olimpo
# Processing Record:77 of set 77 | bluff
# Processing Record:78 of set 78 | kapaa
# Processing Record:79 of set 79 | kontagora
# Processing Record:80 of set 80 | lagoa
# Processing Record:81 of set 81 | nsanje
# Processing Record:82 of set 82 | punta arenas
# Processing Record:83 of set 83 | ilo
# Processing Record:84 of set 84 | cherskiy
# Processing Record:85 of set 85 | basco
# Processing Record:86 of set 86 | avera
# Processing Record:87 of set 87 | svolvaer
# City not found. Skipping...
# Processing Record:88 of set 88 | mount gambier
# Processing Record:89 of set 89 | marovoay
# Processing Record:90 of set 90 | constitucion
# Processing Record:91 of set 91 | orlik
# Processing Record:92 of set 92 | batagay-alyta
# Processing Record:93 of set 93 | dhampur
# Processing Record:94 of set 94 | awbari
# Processing Record:95 of set 95 | castro
# Processing Record:96 of set 96 | maniitsoq
# City not found. Skipping...
# Processing Record:97 of set 97 | punta arenas
# Processing Record:98 of set 98 | severo-kurilsk
# Processing Record:99 of set 99 | suhindol
# Processing Record:100 of set 100 | kaitangata
# Processing Record:101 of set 101 | den helder
# City not found. Skipping...
# Processing Record:102 of set 102 | puerto ayacucho
# Processing Record:103 of set 103 | zhezkazgan
# Processing Record:104 of set 104 | chuy
# City not found. Skipping...
# Processing Record:105 of set 105 | cape town
# City not found. Skipping...
# Processing Record:106 of set 106 | lasa
# Processing Record:107 of set 107 | fort frances
# Processing Record:108 of set 108 | novopetrovskoye
# Processing Record:109 of set 109 | thinadhoo
# City not found. Skipping...
# Processing Record:110 of set 110 | atuona
# Processing Record:111 of set 111 | pucallpa
# Processing Record:112 of set 112 | ekhabi
# Processing Record:113 of set 113 | westport
# City not found. Skipping...
# Processing Record:114 of set 114 | cape town
# Processing Record:115 of set 115 | cape town
# Processing Record:116 of set 116 | male
# Processing Record:117 of set 117 | yellowknife
# Processing Record:118 of set 118 | waipawa
# Processing Record:119 of set 119 | tarko-sale
# Processing Record:120 of set 120 | novopokrovka
# Processing Record:121 of set 121 | navahrudak
# Processing Record:122 of set 122 | punta arenas
# Processing Record:123 of set 123 | torbay
# Processing Record:124 of set 124 | brae
# Processing Record:125 of set 125 | grand-lahou
# Processing Record:126 of set 126 | qaanaaq
# Processing Record:127 of set 127 | nurota
# Processing Record:128 of set 128 | baruun-urt
# Processing Record:129 of set 129 | davidson
# City not found. Skipping...
# Processing Record:130 of set 130 | grindavik
# Processing Record:131 of set 131 | nikolskoye
# Processing Record:132 of set 132 | ypsonas
# Processing Record:133 of set 133 | port hardy
# Processing Record:134 of set 134 | xingyi
# City not found. Skipping...
# Processing Record:135 of set 135 | mogadishu
# Processing Record:136 of set 136 | husavik
# Processing Record:137 of set 137 | carnarvon
# Processing Record:138 of set 138 | japura
# Processing Record:139 of set 139 | obihiro
# Processing Record:140 of set 140 | tiksi
# Processing Record:141 of set 141 | makubetsu
# Processing Record:142 of set 142 | havoysund
# Processing Record:143 of set 143 | klaksvik
# Processing Record:144 of set 144 | oksfjord
# Processing Record:145 of set 145 | faanui
# Processing Record:146 of set 146 | ribeira grande
# Processing Record:147 of set 147 | tabou
# Processing Record:148 of set 148 | punta arenas
# Processing Record:149 of set 149 | acapulco
# Processing Record:150 of set 150 | beyneu
# Processing Record:151 of set 151 | nishihara
# City not found. Skipping...
# Processing Record:152 of set 152 | weligama
# City not found. Skipping...
# Processing Record:153 of set 153 | port hedland
# City not found. Skipping...
# Processing Record:154 of set 154 | fairbanks
# Processing Record:155 of set 155 | lahaina
# Processing Record:156 of set 156 | punta arenas
# City not found. Skipping...
# Processing Record:157 of set 157 | beba
# Processing Record:158 of set 158 | mackay
# Processing Record:159 of set 159 | winsum
# Processing Record:160 of set 160 | punta arenas
# Processing Record:161 of set 161 | alihe
# Processing Record:162 of set 162 | ribeira grande
# Processing Record:163 of set 163 | guerrero negro
# Processing Record:164 of set 164 | kanniyakumari
# Processing Record:165 of set 165 | salalah
# Processing Record:166 of set 166 | mar del plata
# Processing Record:167 of set 167 | chokurdakh
# Processing Record:168 of set 168 | koslan
# Processing Record:169 of set 169 | punta arenas
# Processing Record:170 of set 170 | airai
# Processing Record:171 of set 171 | evensk
# Processing Record:172 of set 172 | sisimiut
# City not found. Skipping...
# Processing Record:173 of set 173 | kudahuvadhoo
# Processing Record:174 of set 174 | san quintin
# Processing Record:175 of set 175 | kahului
# Processing Record:176 of set 176 | omsukchan
# Processing Record:177 of set 177 | padang
# Processing Record:178 of set 178 | champawat
# Processing Record:179 of set 179 | tikapur
# Processing Record:180 of set 180 | bethel
# Processing Record:181 of set 181 | guerrero negro
# Processing Record:182 of set 182 | thunder bay
# Processing Record:183 of set 183 | oistins
# Processing Record:184 of set 184 | punta arenas
# Processing Record:185 of set 185 | broome
# Processing Record:186 of set 186 | bambous virieux
# Processing Record:187 of set 187 | port hedland
# Processing Record:188 of set 188 | khatanga
# Processing Record:189 of set 189 | isangel
# Processing Record:190 of set 190 | new norfolk
# Processing Record:191 of set 191 | magalia
# Processing Record:192 of set 192 | cape town
# City not found. Skipping...
# Processing Record:193 of set 193 | dossor
# Processing Record:194 of set 194 | cape town
# Processing Record:195 of set 195 | maceio
# Processing Record:196 of set 196 | vanderhoof
# City not found. Skipping...
# Processing Record:197 of set 197 | hasaki
# Processing Record:198 of set 198 | tolaga bay
# Processing Record:199 of set 199 | rawson
# Processing Record:200 of set 200 | puerto colombia
# City not found. Skipping...
# Processing Record:201 of set 201 | umm lajj
# Processing Record:202 of set 202 | ostersund
# Processing Record:203 of set 203 | pincher creek
# Processing Record:204 of set 204 | puerto leguizamo
# Processing Record:205 of set 205 | borogontsy
# Processing Record:206 of set 206 | cardenas
# Processing Record:207 of set 207 | punta arenas
# Processing Record:208 of set 208 | sassandra
# Processing Record:209 of set 209 | zarkos
# Processing Record:210 of set 210 | areia branca
# Processing Record:211 of set 211 | terrace
# Processing Record:212 of set 212 | santiago del estero
# Processing Record:213 of set 213 | zaysan
# Processing Record:214 of set 214 | punta arenas
# Processing Record:215 of set 215 | new norfolk
# Processing Record:216 of set 216 | saint george
# Processing Record:217 of set 217 | ribeira grande
# Processing Record:218 of set 218 | bambous virieux
# Processing Record:219 of set 219 | sept-iles
# Processing Record:220 of set 220 | saint george
# Processing Record:221 of set 221 | clyde river
# Processing Record:222 of set 222 | bambanglipuro
# Processing Record:223 of set 223 | floro
# Processing Record:224 of set 224 | saskylakh
# Processing Record:225 of set 225 | robertsport
# Processing Record:226 of set 226 | samarai
# Processing Record:227 of set 227 | waitati
# Processing Record:228 of set 228 | ambon
# Processing Record:229 of set 229 | namtsy
# Processing Record:230 of set 230 | tuktoyaktuk
# Processing Record:231 of set 231 | yumen
# Processing Record:232 of set 232 | codrington
# Processing Record:233 of set 233 | lebu
# Processing Record:234 of set 234 | port augusta
# Processing Record:235 of set 235 | tuatapere
# Processing Record:236 of set 236 | alekseyevsk
# Processing Record:237 of set 237 | kassala
# Processing Record:238 of set 238 | new norfolk
# Processing Record:239 of set 239 | longyearbyen
# Processing Record:240 of set 240 | ocean city
# Processing Record:241 of set 241 | tupik
# Processing Record:242 of set 242 | zhanaozen
# Processing Record:243 of set 243 | port elizabeth
# Processing Record:244 of set 244 | hambantota
# Processing Record:245 of set 245 | hithadhoo
# Processing Record:246 of set 246 | haines junction
# Processing Record:247 of set 247 | paraiso
# Processing Record:248 of set 248 | muros
# Processing Record:249 of set 249 | boyolangu
# Processing Record:250 of set 250 | vegreville
# Processing Record:251 of set 251 | kutum
# City not found. Skipping...
# Processing Record:252 of set 252 | ribeira grande
# City not found. Skipping...
# Processing Record:253 of set 253 | port elizabeth
# Processing Record:254 of set 254 | east london
# Processing Record:255 of set 255 | mar del plata
# Processing Record:256 of set 256 | te anau
# Processing Record:257 of set 257 | el dorado
# Processing Record:258 of set 258 | jalingo
# Processing Record:259 of set 259 | chemax
# Processing Record:260 of set 260 | tasiilaq
# Processing Record:261 of set 261 | punta arenas
# Processing Record:262 of set 262 | cidreira
# Processing Record:263 of set 263 | charters towers
# City not found. Skipping...
# Processing Record:264 of set 264 | punta arenas
# Processing Record:265 of set 265 | pevek
# Processing Record:266 of set 266 | jinchang
# Processing Record:267 of set 267 | puerto ayora
# Processing Record:268 of set 268 | yulara
# Processing Record:269 of set 269 | campbell river
# Processing Record:270 of set 270 | vardo
# Processing Record:271 of set 271 | panguna
# Processing Record:272 of set 272 | genhe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:273 of set 273 | lata
# Processing Record:274 of set 274 | cape town
# Processing Record:275 of set 275 | lebanon
# Processing Record:276 of set 276 | las choapas
# Processing Record:277 of set 277 | mbamba
# Processing Record:278 of set 278 | belaya
# Processing Record:279 of set 279 | sungairaya
# Processing Record:280 of set 280 | poladpur
# City not found. Skipping...
# Processing Record:281 of set 281 | antalaha
# Processing Record:282 of set 282 | gamba
# Processing Record:283 of set 283 | prince rupert
# Processing Record:284 of set 284 | la ronge
# Processing Record:285 of set 285 | inhambane
# Processing Record:286 of set 286 | sauce
# City not found. Skipping...
# Processing Record:287 of set 287 | natal
# Processing Record:288 of set 288 | yurga
# Processing Record:289 of set 289 | nizhnyaya omka
# Processing Record:290 of set 290 | punta arenas
# Processing Record:291 of set 291 | egvekinot
# Processing Record:292 of set 292 | huarmey
# Processing Record:293 of set 293 | dzaoudzi
# Processing Record:294 of set 294 | teknaf
# Processing Record:295 of set 295 | hobyo
# Processing Record:296 of set 296 | imbituba
# Processing Record:297 of set 297 | havre-saint-pierre
# Processing Record:298 of set 298 | portland
# Processing Record:299 of set 299 | maragogi
# Processing Record:300 of set 300 | the pas
# Processing Record:301 of set 301 | broken hill
# Processing Record:302 of set 302 | aklavik
# Processing Record:303 of set 303 | birjand
# Processing Record:304 of set 304 | cartagena
# Processing Record:305 of set 305 | sitka
# Processing Record:306 of set 306 | machico
# Processing Record:307 of set 307 | pochutla
# Processing Record:308 of set 308 | saint anthony
# Processing Record:309 of set 309 | mana
# Processing Record:310 of set 310 | la romana
# Processing Record:311 of set 311 | pangnirtung
# Processing Record:312 of set 312 | sharan
# Processing Record:313 of set 313 | port alfred
# Processing Record:314 of set 314 | cape town
# Processing Record:315 of set 315 | tahe
# Processing Record:316 of set 316 | ponta do sol
# Processing Record:317 of set 317 | sambava
# Processing Record:318 of set 318 | sandy bay
# Processing Record:319 of set 319 | port alfred
# Processing Record:320 of set 320 | palmer
# Processing Record:321 of set 321 | punta arenas
# Processing Record:322 of set 322 | ifanadiana
# Processing Record:323 of set 323 | kamenka
# Processing Record:324 of set 324 | nome
# Processing Record:325 of set 325 | punta arenas
# Processing Record:326 of set 326 | canutama
# Processing Record:327 of set 327 | kavieng
# Processing Record:328 of set 328 | punta arenas
# Processing Record:329 of set 329 | batagay
# Processing Record:330 of set 330 | datong
# Processing Record:331 of set 331 | auburn
# Processing Record:332 of set 332 | barabai
# Processing Record:333 of set 333 | nosy varika
# City not found. Skipping...
# Processing Record:334 of set 334 | cape town
# Processing Record:335 of set 335 | strezhevoy
# Processing Record:336 of set 336 | halifax
# Processing Record:337 of set 337 | provideniya
# Processing Record:338 of set 338 | balabac
# Processing Record:339 of set 339 | punta arenas
# Processing Record:340 of set 340 | la peca
# Processing Record:341 of set 341 | cape town
# Processing Record:342 of set 342 | jining
# Processing Record:343 of set 343 | falmouth
# Processing Record:344 of set 344 | morant bay
# Processing Record:345 of set 345 | new norfolk
# Processing Record:346 of set 346 | kongolo
# City not found. Skipping...
# Processing Record:347 of set 347 | mengcheng
# Processing Record:348 of set 348 | port alfred
# Processing Record:349 of set 349 | zhigansk
# Processing Record:350 of set 350 | russell
# Processing Record:351 of set 351 | mar del plata
# Processing Record:352 of set 352 | zemio
# Processing Record:353 of set 353 | east london
# Processing Record:354 of set 354 | brunsbuttel
# Processing Record:355 of set 355 | ribeira grande
# Processing Record:356 of set 356 | punta arenas
# Processing Record:357 of set 357 | kamuli
# Processing Record:358 of set 358 | la asuncion
# Processing Record:359 of set 359 | cape town
# Processing Record:360 of set 360 | sid
# Processing Record:361 of set 361 | cabo san lucas
# Processing Record:362 of set 362 | nakambala
# Processing Record:363 of set 363 | punta arenas
# City not found. Skipping...
# Processing Record:364 of set 364 | alofi
# Processing Record:365 of set 365 | punta arenas
# Processing Record:366 of set 366 | geraldton
# Processing Record:367 of set 367 | ornskoldsvik
# Processing Record:368 of set 368 | pouebo
# Processing Record:369 of set 369 | prince rupert
# City not found. Skipping...
# Processing Record:370 of set 370 | villa carlos paz
# City not found. Skipping...
# Processing Record:371 of set 371 | tekkali
# Processing Record:372 of set 372 | charlestown
# Processing Record:373 of set 373 | new norfolk
# Processing Record:374 of set 374 | punta arenas
# Processing Record:375 of set 375 | ilulissat
# City not found. Skipping...
# Processing Record:376 of set 376 | san ignacio
# Processing Record:377 of set 377 | bloomingdale
# Processing Record:378 of set 378 | bandundu
# City not found. Skipping...
# Processing Record:379 of set 379 | wajima
# Processing Record:380 of set 380 | kharovsk
# City not found. Skipping...
# Processing Record:381 of set 381 | arraial do cabo
# Processing Record:382 of set 382 | camacha
# Processing Record:383 of set 383 | port hedland
# Processing Record:384 of set 384 | danielskuil
# City not found. Skipping...
# Processing Record:385 of set 385 | coquimbo
# Processing Record:386 of set 386 | xuddur
# Processing Record:387 of set 387 | fare
# Processing Record:388 of set 388 | zyryanka
# Processing Record:389 of set 389 | punta arenas
# Processing Record:390 of set 390 | bambous virieux
# Processing Record:391 of set 391 | bambous virieux
# Processing Record:392 of set 392 | los llanos de aridane
# Processing Record:393 of set 393 | edwardsville
# Processing Record:394 of set 394 | chapais
# Processing Record:395 of set 395 | punta arenas
# Processing Record:396 of set 396 | shingu
# Processing Record:397 of set 397 | port alfred
# Processing Record:398 of set 398 | puerto madryn
# Processing Record:399 of set 399 | camacupa
# Processing Record:400 of set 400 | aswan
# Processing Record:401 of set 401 | atambua
# Processing Record:402 of set 402 | erdenet
# Processing Record:403 of set 403 | catuday
# Processing Record:404 of set 404 | puerto ayora
# Processing Record:405 of set 405 | punta arenas
# Processing Record:406 of set 406 | okhotsk
# Processing Record:407 of set 407 | chipata
# City not found. Skipping...
# Processing Record:408 of set 408 | new norfolk
# Processing Record:409 of set 409 | torrington
# Processing Record:410 of set 410 | marawi
# Processing Record:411 of set 411 | arraial do cabo
# Processing Record:412 of set 412 | lafayette
# Processing Record:413 of set 413 | beringovskiy
# City not found. Skipping...
# Processing Record:414 of set 414 | punta arenas
# Processing Record:415 of set 415 | arraial do cabo
# Processing Record:416 of set 416 | namibe
# City not found. Skipping...
# Processing Record:417 of set 417 | myre
# Processing Record:418 of set 418 | saint george
# Processing Record:419 of set 419 | punta arenas
# Processing Record:420 of set 420 | tautira
# Processing Record:421 of set 421 | east london
# Processing Record:422 of set 422 | redmond
# Processing Record:423 of set 423 | los llanos de aridane
# City not found. Skipping...
# Processing Record:424 of set 424 | port shepstone
# Processing Record:425 of set 425 | najran
# Processing Record:426 of set 426 | punta arenas
# Processing Record:427 of set 427 | binzhou
# Processing Record:428 of set 428 | constantine
# Processing Record:429 of set 429 | sidi ali
# Processing Record:430 of set 430 | college
# Processing Record:431 of set 431 | juli
# Processing Record:432 of set 432 | road town
# Processing Record:433 of set 433 | mahina
# Processing Record:434 of set 434 | atasu
# Processing Record:435 of set 435 | port macquarie
# Processing Record:436 of set 436 | kayerkan
# Processing Record:437 of set 437 | flinders
# Processing Record:438 of set 438 | east london
# Processing Record:439 of set 439 | new norfolk
# Processing Record:440 of set 440 | ovada
# Processing Record:441 of set 441 | port hardy
# Processing Record:442 of set 442 | te anau
# Processing Record:443 of set 443 | maldonado
# Processing Record:444 of set 444 | punta arenas
# Processing Record:445 of set 445 | ibipeba
# Processing Record:446 of set 446 | punta arenas
# Processing Record:447 of set 447 | urengoy
# Processing Record:448 of set 448 | ust-charyshskaya pristan
# Processing Record:449 of set 449 | port elizabeth
# Processing Record:450 of set 450 | punta arenas
# Processing Record:451 of set 451 | port blair
# Processing Record:452 of set 452 | atar
# Processing Record:453 of set 453 | malyye derbety
# Processing Record:454 of set 454 | ewa beach
# Processing Record:455 of set 455 | sao filipe
# Processing Record:456 of set 456 | los llanos de aridane
# Processing Record:457 of set 457 | souillac
# Processing Record:458 of set 458 | methoni
# Processing Record:459 of set 459 | sorso
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:460 of set 460 | mar del plata
# Processing Record:461 of set 461 | bogorodskoye
# Processing Record:462 of set 462 | cape town
# Processing Record:463 of set 463 | cape town
# Processing Record:464 of set 464 | cabo san lucas
# Processing Record:465 of set 465 | bambous virieux
# City not found. Skipping...
# Processing Record:466 of set 466 | cabo san lucas
# Processing Record:467 of set 467 | fortuna
# Processing Record:468 of set 468 | cayenne
# City not found. Skipping...
# Processing Record:469 of set 469 | rocha
# Processing Record:470 of set 470 | east london
# Processing Record:471 of set 471 | kattivakkam
# Processing Record:472 of set 472 | new norfolk
# Processing Record:473 of set 473 | bitam
# Processing Record:474 of set 474 | banga
# Processing Record:475 of set 475 | berlevag
# Processing Record:476 of set 476 | punta arenas
# Processing Record:477 of set 477 | winchester
# Processing Record:478 of set 478 | bambous virieux
# Processing Record:479 of set 479 | buenaventura
# Processing Record:480 of set 480 | east london
# Processing Record:481 of set 481 | mae chan
# City not found. Skipping...
# Processing Record:482 of set 482 | kastamonu
# Processing Record:483 of set 483 | tondano
# Processing Record:484 of set 484 | araouane
# Processing Record:485 of set 485 | colquechaca
# City not found. Skipping...
# Processing Record:486 of set 486 | prainha
# Processing Record:487 of set 487 | poli
# City not found. Skipping...
# Processing Record:488 of set 488 | fort smith
# Processing Record:489 of set 489 | port elizabeth
# Processing Record:490 of set 490 | mar del plata
# Processing Record:491 of set 491 | port alfred
# Processing Record:492 of set 492 | bulgan
# Processing Record:493 of set 493 | port elizabeth
# Processing Record:494 of set 494 | naze
# Processing Record:495 of set 495 | banjar
# City not found. Skipping...
# Processing Record:496 of set 496 | porto velho
# Processing Record:497 of set 497 | east london
# Processing Record:498 of set 498 | songea
# Processing Record:499 of set 499 | arraial do cabo
# Processing Record:500 of set 500 | cape town
# Processing Record:501 of set 501 | golega
# City not found. Skipping...
# Processing Record:502 of set 502 | mar del plata
# Processing Record:503 of set 503 | cumbum
# Processing Record:504 of set 504 | aviemore
# Processing Record:505 of set 505 | lagunas
# Processing Record:506 of set 506 | ribeira grande
# Processing Record:507 of set 507 | alcaniz
# Processing Record:508 of set 508 | gbadolite
# Processing Record:509 of set 509 | puerto ayora
# Processing Record:510 of set 510 | bahia honda
# Processing Record:511 of set 511 | xining
# Processing Record:512 of set 512 | ribeira grande
# Processing Record:513 of set 513 | yining
# Processing Record:514 of set 514 | liancheng
# City not found. Skipping...
# Processing Record:515 of set 515 | la ronge
# Processing Record:516 of set 516 | kyren
# Processing Record:517 of set 517 | vila do maio
# Processing Record:518 of set 518 | ponta do sol
# Processing Record:519 of set 519 | cumberland
# Processing Record:520 of set 520 | san quintin
# Processing Record:521 of set 521 | yagodnoye
# Processing Record:522 of set 522 | hami
# Processing Record:523 of set 523 | taltal
# Processing Record:524 of set 524 | mahibadhoo
# Processing Record:525 of set 525 | ribeira grande
# Processing Record:526 of set 526 | lorengau
# Processing Record:527 of set 527 | khandyga
# Processing Record:528 of set 528 | tarkwa
# City not found. Skipping...
# Processing Record:529 of set 529 | adrian
# Processing Record:530 of set 530 | tecoanapa
# Processing Record:531 of set 531 | ratanpur
# Processing Record:532 of set 532 | iqaluit
# Processing Record:533 of set 533 | port elizabeth
# Processing Record:534 of set 534 | ilinskiy
# Processing Record:535 of set 535 | greencastle
# City not found. Skipping...
# Processing Record:536 of set 536 | luanda
# Processing Record:537 of set 537 | sola
# Processing Record:538 of set 538 | coihaique
# Processing Record:539 of set 539 | la ronge
# Processing Record:540 of set 540 | mar del plata
# Processing Record:541 of set 541 | dunedin
# Processing Record:542 of set 542 | laguna
# Processing Record:543 of set 543 | punta arenas
# Processing Record:544 of set 544 | san patricio
# City not found. Skipping...
# Processing Record:545 of set 545 | port hedland
# Processing Record:546 of set 546 | sioux lookout
# Processing Record:547 of set 547 | byron bay
# Processing Record:548 of set 548 | east london
# Processing Record:549 of set 549 | cape town
# Processing Record:550 of set 550 | pio xii
# Processing Record:551 of set 551 | punta arenas
# Processing Record:552 of set 552 | kondinskoye
# Processing Record:553 of set 553 | emmett
# Processing Record:554 of set 554 | jhalida
# Processing Record:555 of set 555 | lazaro cardenas
# Processing Record:556 of set 556 | chor
# Processing Record:557 of set 557 | coffs harbour
# Processing Record:558 of set 558 | bambous virieux
# Processing Record:559 of set 559 | dapaong
# Processing Record:560 of set 560 | villarrica
# Processing Record:561 of set 561 | punta arenas
# Processing Record:562 of set 562 | mantua
# Processing Record:563 of set 563 | dikson
# Processing Record:564 of set 564 | punta arenas
# Processing Record:565 of set 565 | yuzhou
# Processing Record:566 of set 566 | emba
# Processing Record:567 of set 567 | mar del plata
# Processing Record:568 of set 568 | kjollefjord
# Processing Record:569 of set 569 | tombouctou
# Processing Record:570 of set 570 | san cristobal
# Processing Record:571 of set 571 | kijang
# Processing Record:572 of set 572 | manta
# City not found. Skipping...
# Processing Record:573 of set 573 | wexford
# Processing Record:574 of set 574 | dhidhdhoo
# Processing Record:575 of set 575 | punta arenas
# Processing Record:576 of set 576 | ossora
# City not found. Skipping...
# Processing Record:577 of set 577 | coolum beach
# Processing Record:578 of set 578 | cabo san lucas
# Processing Record:579 of set 579 | touros
# Processing Record:580 of set 580 | cheney
# Processing Record:581 of set 581 | vila velha
# Processing Record:582 of set 582 | saint pete beach
# Processing Record:583 of set 583 | lujan
# Processing Record:584 of set 584 | havelock
# Processing Record:585 of set 585 | pocosol
# Processing Record:586 of set 586 | pathein
# Processing Record:587 of set 587 | nyurba
# Processing Record:588 of set 588 | askiz
# Processing Record:589 of set 589 | bandarbeyla
# City not found. Skipping...
# Processing Record:590 of set 590 | cape town
# Processing Record:591 of set 591 | angoram
# Processing Record:592 of set 592 | hovd
# Processing Record:593 of set 593 | hauzenberg
# Processing Record:594 of set 594 | kununurra
# Processing Record:595 of set 595 | saint george
# Processing Record:596 of set 596 | buluang
# City not found. Skipping...
# Processing Record:597 of set 597 | hohhot
# Processing Record:598 of set 598 | ostrovnoy
# Processing Record:599 of set 599 | esperance
# Processing Record:600 of set 600 | guilin
# Processing Record:601 of set 601 | margate
# Processing Record:602 of set 602 | ergani
# Processing Record:603 of set 603 | piacabucu
# Processing Record:604 of set 604 | nanortalik
# Processing Record:605 of set 605 | cape town
# Processing Record:606 of set 606 | coahuayana
# Processing Record:607 of set 607 | ihosy
# Processing Record:608 of set 608 | san patricio
# Processing Record:609 of set 609 | port alfred
# Processing Record:610 of set 610 | port alfred
# Processing Record:611 of set 611 | bacolod
# Processing Record:612 of set 612 | lexington park
# Processing Record:613 of set 613 | los llanos de aridane
# Processing Record:614 of set 614 | luderitz
# Processing Record:615 of set 615 | port alfred
# Processing Record:616 of set 616 | punta arenas
# Processing Record:617 of set 617 | jubbal
# Processing Record:618 of set 618 | roebourne
# Processing Record:619 of set 619 | touho
# Processing Record:620 of set 620 | grand gaube
# Processing Record:621 of set 621 | ndola
# Processing Record:622 of set 622 | muli
# Processing Record:623 of set 623 | punta arenas
# Processing Record:624 of set 624 | nizwa
# Processing Record:625 of set 625 | mungaa
# Processing Record:626 of set 626 | shu
# Processing Record:627 of set 627 | orbetello
# Processing Record:628 of set 628 | salinas
# Processing Record:629 of set 629 | beira
# Processing Record:630 of set 630 | new norfolk
# Processing Record:631 of set 631 | mlonggo
# Processing Record:632 of set 632 | varzea grande
# Processing Record:633 of set 633 | punta arenas
# Processing Record:634 of set 634 | pizarro
# Processing Record:635 of set 635 | norman wells
# Processing Record:636 of set 636 | springfield
# Processing Record:637 of set 637 | porto novo
# Processing Record:638 of set 638 | sorland
# Processing Record:639 of set 639 | punta arenas
# Processing Record:640 of set 640 | nemuro
# Processing Record:641 of set 641 | nhulunbuy
# Processing Record:642 of set 642 | punta arenas
# City not found. Skipping...
# Processing Record:643 of set 643 | saint-pierre
# Processing Record:644 of set 644 | ishigaki
# Processing Record:645 of set 645 | ca mau
# Processing Record:646 of set 646 | manokwari
# Processing Record:647 of set 647 | anadyr
# City not found. Skipping...
# Processing Record:648 of set 648 | tyukhtet
# Processing Record:649 of set 649 | fengrun
# Processing Record:650 of set 650 | kampong cham
# Processing Record:651 of set 651 | mount gambier
# Processing Record:652 of set 652 | haines junction
# Processing Record:653 of set 653 | hofn
# Processing Record:654 of set 654 | boguchany
# Processing Record:655 of set 655 | bagdarin
# Processing Record:656 of set 656 | new norfolk
# Processing Record:657 of set 657 | nova odesa
# Processing Record:658 of set 658 | leh
# Processing Record:659 of set 659 | cabo san lucas
# Processing Record:660 of set 660 | port elizabeth
# Processing Record:661 of set 661 | punta arenas
# Processing Record:662 of set 662 | garissa
# Processing Record:663 of set 663 | paamiut
# Processing Record:664 of set 664 | kalmunai
# Processing Record:665 of set 665 | arraial do cabo
# Processing Record:666 of set 666 | mendi
# Processing Record:667 of set 667 | punta arenas
# Processing Record:668 of set 668 | ribeira brava
# Processing Record:669 of set 669 | ylivieska
# Processing Record:670 of set 670 | kaeo
# Processing Record:671 of set 671 | merauke
# Processing Record:672 of set 672 | coffs harbour
# Processing Record:673 of set 673 | port lincoln
# Processing Record:674 of set 674 | norman wells
# Processing Record:675 of set 675 | gumdag
# Processing Record:676 of set 676 | east london
# Processing Record:677 of set 677 | presidencia roque saenz pena
# Processing Record:678 of set 678 | puerto ayora
# City not found. Skipping...
# Processing Record:679 of set 679 | vila velha
# Processing Record:680 of set 680 | champerico
# City not found. Skipping...
# City not found. Skipping...
# Processing Record:681 of set 681 | ulladulla
# Processing Record:682 of set 682 | satis
# City not found. Skipping...
# Processing Record:683 of set 683 | walvis bay
# Processing Record:684 of set 684 | jardim
# Processing Record:685 of set 685 | plouzane
# Processing Record:686 of set 686 | port elizabeth
# Processing Record:687 of set 687 | puerto escondido
# Processing Record:688 of set 688 | nantucket
# Processing Record:689 of set 689 | pingxiang
# Processing Record:690 of set 690 | shimanovsk
# Processing Record:691 of set 691 | roma
# Processing Record:692 of set 692 | garowe
# City not found. Skipping...
# Processing Record:693 of set 693 | bima
# Processing Record:694 of set 694 | rabo de peixe
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
data_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}
#create the dataframe 
data_df = pd.DataFrame(data_dict)

# display the count 
data_df.count()
# Out:
# City          694
# Cloudiness    694
# Country       694
# Date          694
# Humidity      694
# Lat           694
# Lng           694
# Max Temp      694
# Wind Speed    694
# dtype: int64

# %%
#display the Dataframe
data_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            Vao          68      EE  1544341526        97  59.10   26.19
# 1     Georgetown          20      GY  1544338800        94   6.80  -58.16
# 2     Butaritari          64      KI  1544341527       100   3.07  172.79
# 3  Sioux Lookout          20      CA  1544338800        78  50.10  -91.92
# 4         Beloha           0      MG  1544341527        42 -25.17   45.06
#
#    Max Temp  Wind Speed
# 0   275.150        6.23
# 1   296.150        1.00
# 2   302.074        1.83
# 3   263.150        2.10
# 4   309.424        2.01

# %%
#export to CSV 
with open('Output_csv/data_file.csv', mode='w') as csv_file:
    fieldnames = data_dict
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow(data_dict)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(data_df["Lat"], data_df["Max Temp"], marker="o", s=10)
#Graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(data_df["Lat"], data_df["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(data_df["Lat"], data_df["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(data_df["Lat"], data_df["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
